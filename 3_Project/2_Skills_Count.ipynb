# %%
Test_job = ['Test Job1', 'Test Job2', 'Test Job3']
Test_job
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 Test_job : ['Test Job1', 'Test Job2', 'Test Job3']
# ----> 2 Test_job
#
# NameError: name 'Test_job' is not defined
